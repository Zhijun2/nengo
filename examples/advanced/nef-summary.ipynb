# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1875981719" href="javascript:toggle_input_1875981719()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1875981719;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1875981719 = document.getElementById("1875981719");
#                 var cell = link_1875981719;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1875981719;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1875981719 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1875981719 = cell.previousElementSibling;
#                 }
#                 input_1875981719.style.display = "none"; // hide
#
#                 toggle_input_1875981719 = function() {
#                     if (input_1875981719.style.display == "none") {
#                         input_1875981719.style.display = ""; // show
#                         link_1875981719.innerHTML = "Hide Input";
#                     } else {
#                         input_1875981719.style.display = "none"; // hide
#                         link_1875981719.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1875981719 = $("a[id='1875981719']");
#                 var cell_1875981719 = link_1875981719.parents("div.cell:first");
#                 if (cell_1875981719.length == 0) {
#                     cell_1875981719 = link_1875981719.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1875981719 = cell_1875981719.children("div.input");
#                 if (input_1875981719.length == 0) {
#                     input_1875981719 = cell_1875981719.prev("div.nbinput");
#                 }
#                 input_1875981719.hide();
#
#                 toggle_input_1875981719 = function() {
#                     if (input_1875981719.is(':hidden')) {
#                         input_1875981719.slideDown();
#                         link_1875981719[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1875981719.slideUp();
#                         link_1875981719[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1296879699" href="javascript:toggle_input_1296879699()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1296879699;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1296879699 = document.getElementById("1296879699");
#                 var cell = link_1296879699;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1296879699;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1296879699 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1296879699 = cell.previousElementSibling;
#                 }
#                 input_1296879699.style.display = "none"; // hide
#
#                 toggle_input_1296879699 = function() {
#                     if (input_1296879699.style.display == "none") {
#                         input_1296879699.style.display = ""; // show
#                         link_1296879699.innerHTML = "Hide Input";
#                     } else {
#                         input_1296879699.style.display = "none"; // hide
#                         link_1296879699.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1296879699 = $("a[id='1296879699']");
#                 var cell_1296879699 = link_1296879699.parents("div.cell:first");
#                 if (cell_1296879699.length == 0) {
#                     cell_1296879699 = link_1296879699.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1296879699 = cell_1296879699.children("div.input");
#                 if (input_1296879699.length == 0) {
#                     input_1296879699 = cell_1296879699.prev("div.nbinput");
#                 }
#                 input_1296879699.hide();
#
#                 toggle_input_1296879699 = function() {
#                     if (input_1296879699.is(':hidden')) {
#                         input_1296879699.slideDown();
#                         link_1296879699[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1296879699.slideUp();
#                         link_1296879699[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="962770619" href="javascript:toggle_input_962770619()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_962770619;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_962770619 = document.getElementById("962770619");
#                 var cell = link_962770619;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_962770619;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_962770619 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_962770619 = cell.previousElementSibling;
#                 }
#                 input_962770619.style.display = "none"; // hide
#
#                 toggle_input_962770619 = function() {
#                     if (input_962770619.style.display == "none") {
#                         input_962770619.style.display = ""; // show
#                         link_962770619.innerHTML = "Hide Input";
#                     } else {
#                         input_962770619.style.display = "none"; // hide
#                         link_962770619.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_962770619 = $("a[id='962770619']");
#                 var cell_962770619 = link_962770619.parents("div.cell:first");
#                 if (cell_962770619.length == 0) {
#                     cell_962770619 = link_962770619.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_962770619 = cell_962770619.children("div.input");
#                 if (input_962770619.length == 0) {
#                     input_962770619 = cell_962770619.prev("div.nbinput");
#                 }
#                 input_962770619.hide();
#
#                 toggle_input_962770619 = function() {
#                     if (input_962770619.is(':hidden')) {
#                         input_962770619.slideDown();
#                         link_962770619[0].innerHTML = "Hide Input";
#                     } else {
#                         input_962770619.slideUp();
#                         link_962770619[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="1640571400" href="javascript:toggle_input_1640571400()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1640571400;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1640571400 = document.getElementById("1640571400");
#                 var cell = link_1640571400;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1640571400;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1640571400 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1640571400 = cell.previousElementSibling;
#                 }
#                 input_1640571400.style.display = "none"; // hide
#
#                 toggle_input_1640571400 = function() {
#                     if (input_1640571400.style.display == "none") {
#                         input_1640571400.style.display = ""; // show
#                         link_1640571400.innerHTML = "Hide Input";
#                     } else {
#                         input_1640571400.style.display = "none"; // hide
#                         link_1640571400.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1640571400 = $("a[id='1640571400']");
#                 var cell_1640571400 = link_1640571400.parents("div.cell:first");
#                 if (cell_1640571400.length == 0) {
#                     cell_1640571400 = link_1640571400.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1640571400 = cell_1640571400.children("div.input");
#                 if (input_1640571400.length == 0) {
#                     input_1640571400 = cell_1640571400.prev("div.nbinput");
#                 }
#                 input_1640571400.hide();
#
#                 toggle_input_1640571400 = function() {
#                     if (input_1640571400.is(':hidden')) {
#                         input_1640571400.slideDown();
#                         link_1640571400[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1640571400.slideUp();
#                         link_1640571400[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1836696352" href="javascript:toggle_input_1836696352()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1836696352;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1836696352 = document.getElementById("1836696352");
#                 var cell = link_1836696352;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1836696352;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1836696352 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1836696352 = cell.previousElementSibling;
#                 }
#                 input_1836696352.style.display = "none"; // hide
#
#                 toggle_input_1836696352 = function() {
#                     if (input_1836696352.style.display == "none") {
#                         input_1836696352.style.display = ""; // show
#                         link_1836696352.innerHTML = "Hide Input";
#                     } else {
#                         input_1836696352.style.display = "none"; // hide
#                         link_1836696352.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1836696352 = $("a[id='1836696352']");
#                 var cell_1836696352 = link_1836696352.parents("div.cell:first");
#                 if (cell_1836696352.length == 0) {
#                     cell_1836696352 = link_1836696352.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1836696352 = cell_1836696352.children("div.input");
#                 if (input_1836696352.length == 0) {
#                     input_1836696352 = cell_1836696352.prev("div.nbinput");
#                 }
#                 input_1836696352.hide();
#
#                 toggle_input_1836696352 = function() {
#                     if (input_1836696352.is(':hidden')) {
#                         input_1836696352.slideDown();
#                         link_1836696352[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1836696352.slideUp();
#                         link_1836696352[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="2049851616" href="javascript:toggle_input_2049851616()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2049851616;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2049851616 = document.getElementById("2049851616");
#                 var cell = link_2049851616;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2049851616;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2049851616 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2049851616 = cell.previousElementSibling;
#                 }
#                 input_2049851616.style.display = "none"; // hide
#
#                 toggle_input_2049851616 = function() {
#                     if (input_2049851616.style.display == "none") {
#                         input_2049851616.style.display = ""; // show
#                         link_2049851616.innerHTML = "Hide Input";
#                     } else {
#                         input_2049851616.style.display = "none"; // hide
#                         link_2049851616.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2049851616 = $("a[id='2049851616']");
#                 var cell_2049851616 = link_2049851616.parents("div.cell:first");
#                 if (cell_2049851616.length == 0) {
#                     cell_2049851616 = link_2049851616.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2049851616 = cell_2049851616.children("div.input");
#                 if (input_2049851616.length == 0) {
#                     input_2049851616 = cell_2049851616.prev("div.nbinput");
#                 }
#                 input_2049851616.hide();
#
#                 toggle_input_2049851616 = function() {
#                     if (input_2049851616.is(':hidden')) {
#                         input_2049851616.slideDown();
#                         link_2049851616[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2049851616.slideUp();
#                         link_2049851616[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="80623415" href="javascript:toggle_input_80623415()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_80623415;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_80623415 = document.getElementById("80623415");
#                 var cell = link_80623415;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_80623415;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_80623415 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_80623415 = cell.previousElementSibling;
#                 }
#                 input_80623415.style.display = "none"; // hide
#
#                 toggle_input_80623415 = function() {
#                     if (input_80623415.style.display == "none") {
#                         input_80623415.style.display = ""; // show
#                         link_80623415.innerHTML = "Hide Input";
#                     } else {
#                         input_80623415.style.display = "none"; // hide
#                         link_80623415.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_80623415 = $("a[id='80623415']");
#                 var cell_80623415 = link_80623415.parents("div.cell:first");
#                 if (cell_80623415.length == 0) {
#                     cell_80623415 = link_80623415.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_80623415 = cell_80623415.children("div.input");
#                 if (input_80623415.length == 0) {
#                     input_80623415 = cell_80623415.prev("div.nbinput");
#                 }
#                 input_80623415.hide();
#
#                 toggle_input_80623415 = function() {
#                     if (input_80623415.is(':hidden')) {
#                         input_80623415.slideDown();
#                         link_80623415[0].innerHTML = "Hide Input";
#                     } else {
#                         input_80623415.slideUp();
#                         link_80623415[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1616575756" href="javascript:toggle_input_1616575756()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1616575756;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1616575756 = document.getElementById("1616575756");
#                 var cell = link_1616575756;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1616575756;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1616575756 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1616575756 = cell.previousElementSibling;
#                 }
#                 input_1616575756.style.display = "none"; // hide
#
#                 toggle_input_1616575756 = function() {
#                     if (input_1616575756.style.display == "none") {
#                         input_1616575756.style.display = ""; // show
#                         link_1616575756.innerHTML = "Hide Input";
#                     } else {
#                         input_1616575756.style.display = "none"; // hide
#                         link_1616575756.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1616575756 = $("a[id='1616575756']");
#                 var cell_1616575756 = link_1616575756.parents("div.cell:first");
#                 if (cell_1616575756.length == 0) {
#                     cell_1616575756 = link_1616575756.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1616575756 = cell_1616575756.children("div.input");
#                 if (input_1616575756.length == 0) {
#                     input_1616575756 = cell_1616575756.prev("div.nbinput");
#                 }
#                 input_1616575756.hide();
#
#                 toggle_input_1616575756 = function() {
#                     if (input_1616575756.is(':hidden')) {
#                         input_1616575756.slideDown();
#                         link_1616575756[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1616575756.slideUp();
#                         link_1616575756[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="757941593" href="javascript:toggle_input_757941593()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_757941593;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_757941593 = document.getElementById("757941593");
#                 var cell = link_757941593;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_757941593;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_757941593 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_757941593 = cell.previousElementSibling;
#                 }
#                 input_757941593.style.display = "none"; // hide
#
#                 toggle_input_757941593 = function() {
#                     if (input_757941593.style.display == "none") {
#                         input_757941593.style.display = ""; // show
#                         link_757941593.innerHTML = "Hide Input";
#                     } else {
#                         input_757941593.style.display = "none"; // hide
#                         link_757941593.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_757941593 = $("a[id='757941593']");
#                 var cell_757941593 = link_757941593.parents("div.cell:first");
#                 if (cell_757941593.length == 0) {
#                     cell_757941593 = link_757941593.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_757941593 = cell_757941593.children("div.input");
#                 if (input_757941593.length == 0) {
#                     input_757941593 = cell_757941593.prev("div.nbinput");
#                 }
#                 input_757941593.hide();
#
#                 toggle_input_757941593 = function() {
#                     if (input_757941593.is(':hidden')) {
#                         input_757941593.slideDown();
#                         link_757941593[0].innerHTML = "Hide Input";
#                     } else {
#                         input_757941593.slideUp();
#                         link_757941593[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1656929013" href="javascript:toggle_input_1656929013()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1656929013;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1656929013 = document.getElementById("1656929013");
#                 var cell = link_1656929013;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1656929013;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1656929013 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1656929013 = cell.previousElementSibling;
#                 }
#                 input_1656929013.style.display = "none"; // hide
#
#                 toggle_input_1656929013 = function() {
#                     if (input_1656929013.style.display == "none") {
#                         input_1656929013.style.display = ""; // show
#                         link_1656929013.innerHTML = "Hide Input";
#                     } else {
#                         input_1656929013.style.display = "none"; // hide
#                         link_1656929013.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1656929013 = $("a[id='1656929013']");
#                 var cell_1656929013 = link_1656929013.parents("div.cell:first");
#                 if (cell_1656929013.length == 0) {
#                     cell_1656929013 = link_1656929013.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1656929013 = cell_1656929013.children("div.input");
#                 if (input_1656929013.length == 0) {
#                     input_1656929013 = cell_1656929013.prev("div.nbinput");
#                 }
#                 input_1656929013.hide();
#
#                 toggle_input_1656929013 = function() {
#                     if (input_1656929013.is(':hidden')) {
#                         input_1656929013.slideDown();
#                         link_1656929013[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1656929013.slideUp();
#                         link_1656929013[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1925382617" href="javascript:toggle_input_1925382617()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1925382617;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1925382617 = document.getElementById("1925382617");
#                 var cell = link_1925382617;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1925382617;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1925382617 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1925382617 = cell.previousElementSibling;
#                 }
#                 input_1925382617.style.display = "none"; // hide
#
#                 toggle_input_1925382617 = function() {
#                     if (input_1925382617.style.display == "none") {
#                         input_1925382617.style.display = ""; // show
#                         link_1925382617.innerHTML = "Hide Input";
#                     } else {
#                         input_1925382617.style.display = "none"; // hide
#                         link_1925382617.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1925382617 = $("a[id='1925382617']");
#                 var cell_1925382617 = link_1925382617.parents("div.cell:first");
#                 if (cell_1925382617.length == 0) {
#                     cell_1925382617 = link_1925382617.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1925382617 = cell_1925382617.children("div.input");
#                 if (input_1925382617.length == 0) {
#                     input_1925382617 = cell_1925382617.prev("div.nbinput");
#                 }
#                 input_1925382617.hide();
#
#                 toggle_input_1925382617 = function() {
#                     if (input_1925382617.is(':hidden')) {
#                         input_1925382617.slideDown();
#                         link_1925382617[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1925382617.slideUp();
#                         link_1925382617[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1979924903" href="javascript:toggle_input_1979924903()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1979924903;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1979924903 = document.getElementById("1979924903");
#                 var cell = link_1979924903;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1979924903;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1979924903 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1979924903 = cell.previousElementSibling;
#                 }
#                 input_1979924903.style.display = "none"; // hide
#
#                 toggle_input_1979924903 = function() {
#                     if (input_1979924903.style.display == "none") {
#                         input_1979924903.style.display = ""; // show
#                         link_1979924903.innerHTML = "Hide Input";
#                     } else {
#                         input_1979924903.style.display = "none"; // hide
#                         link_1979924903.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1979924903 = $("a[id='1979924903']");
#                 var cell_1979924903 = link_1979924903.parents("div.cell:first");
#                 if (cell_1979924903.length == 0) {
#                     cell_1979924903 = link_1979924903.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1979924903 = cell_1979924903.children("div.input");
#                 if (input_1979924903.length == 0) {
#                     input_1979924903 = cell_1979924903.prev("div.nbinput");
#                 }
#                 input_1979924903.hide();
#
#                 toggle_input_1979924903 = function() {
#                     if (input_1979924903.is(':hidden')) {
#                         input_1979924903.slideDown();
#                         link_1979924903[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1979924903.slideUp();
#                         link_1979924903[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="1199250578" href="javascript:toggle_input_1199250578()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1199250578;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1199250578 = document.getElementById("1199250578");
#                 var cell = link_1199250578;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1199250578;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1199250578 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1199250578 = cell.previousElementSibling;
#                 }
#                 input_1199250578.style.display = "none"; // hide
#
#                 toggle_input_1199250578 = function() {
#                     if (input_1199250578.style.display == "none") {
#                         input_1199250578.style.display = ""; // show
#                         link_1199250578.innerHTML = "Hide Input";
#                     } else {
#                         input_1199250578.style.display = "none"; // hide
#                         link_1199250578.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1199250578 = $("a[id='1199250578']");
#                 var cell_1199250578 = link_1199250578.parents("div.cell:first");
#                 if (cell_1199250578.length == 0) {
#                     cell_1199250578 = link_1199250578.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1199250578 = cell_1199250578.children("div.input");
#                 if (input_1199250578.length == 0) {
#                     input_1199250578 = cell_1199250578.prev("div.nbinput");
#                 }
#                 input_1199250578.hide();
#
#                 toggle_input_1199250578 = function() {
#                     if (input_1199250578.is(':hidden')) {
#                         input_1199250578.slideDown();
#                         link_1199250578[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1199250578.slideUp();
#                         link_1199250578[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
